# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
df=pd.read_csv('/drive/My Drive/Datasets/CarPrice.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# # Data Cleaning and Preparation

# %%
df.head(1)
# Out:
#    car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0       1          3  alfa-romero giulia      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
#
# [1 rows x 26 columns]

# %%
l=[]
for i in df['CarName']:
  x=i.split(' ')
  l.append(x[0])

# %%
Companyname = df['CarName'].apply(lambda x : x.split(' ')[0])
df.insert(3,'CompanyName', Companyname)

# %%
df = df.drop('CarName', axis=1)

# %%
df['CompanyName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df['CompanyName'] = df['CompanyName'].str.lower()

# %%
def replace_name(a,b):
  df['CompanyName'] = df['CompanyName'].replace(a,b)

# %%
replace_name('maxda','mazda')
replace_name('porcshce','porsche')
replace_name('toyouta','toyota')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CompanyName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df=df.drop('car_ID', axis=1)

# %%
Colc = []
for c in df.columns:
  if df[c].dtypes =='object':
    Colc.append(c)
  else:
    continue
Colc
# Out:
# ['CompanyName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
Coln = []
for c in df.columns:
  if df[c].dtypes !='object':
    Coln.append(c)
  else:
    continue
Coln
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
for c in Coln:
  
  q1=df[c].quantile(0.25)
  q3=df[c].quantile(0.75)
  IQR = q3-q1
  upper_limit = IQR + (1.5*q3)
  lower_limit = IQR - (1.5*q1)
  df=df[(df[c]<=upper_limit) & (df[c]>=lower_limit)]
  plt.figure()
  sns.boxplot(data=df, x=df[c])

# %%
df1 = df.corr()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data = df1[(df1>0.5) | (df1> - 0.5)], annot =True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, y='price', x='carbody')
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, y='price', x='doornumber')
# Out:
# <AxesSubplot:xlabel='doornumber', ylabel='price'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, y='price', x='drivewheel')
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='price'>

# %%
sns.relplot(data=df, x='boreratio', y='price', col='carbody', hue='carbody')

# %%
sns.relplot(data=df, x='enginesize', y='price', col='carbody', hue='carbody')

# %%
sns.relplot(data=df, x='horsepower', y='price', col='carbody', hue='carbody')

# %%
sns.relplot(data=df, x='peakrpm', y='price', col='carbody', hue='carbody')
